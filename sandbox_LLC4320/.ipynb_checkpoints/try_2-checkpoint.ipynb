# %%
import os
from glob import glob
import dask
import xarray as xr
import xrft
import cartopy.crs as ccrs
#from cmocean import cm
import numpy as np
from netCDF4 import Dataset
from scipy.io import loadmat

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from dask.distributed import Client, LocalCluster
cluster = LocalCluster()
client = Client(cluster)
client
# Out:
# <Client: 'tcp://127.0.0.1:40373' processes=16 threads=128, memory=251.08 GiB>

# %%
client.dashboard_link
# Out:
# 'http://127.0.0.1:8787/status'

# %%
LLC_data_folder = '/meddy/yuxlong5/data/SCS_LLC4320/'

# %%
ds = xr.open_zarr(LLC_data_folder+'llc_0.zarr')
print(ds)
print('\n data size: %.1f GB' %(ds.nbytes / 1e9))
# Out:
# <xarray.Dataset>
# Dimensions:  (j: 1501, i: 1501, time: 2147, k: 90, k_p1: 91, i_g: 1501,
#               j_g: 1501, k_l: 90, k_u: 90)
# Coordinates: (12/33)
#     CS       (j, i) float32 dask.array<chunksize=(1501, 1501), meta=np.ndarray>
#     Depth    (j, i) float32 dask.array<chunksize=(1501, 1501), meta=np.ndarray>
#     PHrefC   (k) float32 dask.array<chunksize=(90,), meta=np.ndarray>
#     PHrefF   (k_p1) float32 dask.array<chunksize=(91,), meta=np.ndarray>
#     SN       (j, i) float32 dask.array<chunksize=(1501, 1501), meta=np.ndarray>
#     XC       (j, i) float32 dask.array<chunksize=(1501, 1501), meta=np.ndarray>
#     ...       ...
#     niter    (time) int64 dask.array<chunksize=(2147,), meta=np.ndarray>
#     rA       (j, i) float32 dask.array<chunksize=(1501, 1501), meta=np.ndarray>
#     rAs      (j_g, i) float32 dask.array<chunksize=(1501, 1501), meta=np.ndarray>
#     rAw      (j, i_g) float32 dask.array<chunksize=(1501, 1501), meta=np.ndarray>
#     rAz      (j_g, i_g) float32 dask.array<chunksize=(1501, 1501), meta=np.ndarray>
#   * time     (time) datetime64[ns] 2011-11-23T08:00:00 ... 2012-02-20T18:00:00
# Data variables:
#     Eta      (time, j, i) float32 dask.array<chunksize=(1, 1501, 1501), meta=np.ndarray>
#     KPPhbl   (time, j, i) float32 dask.array<chunksize=(1, 1501, 1501), meta=np.ndarray>
#     SSS      (time, j, i) float32 dask.array<chunksize=(1, 1501, 1501), meta=np.ndarray>
#     SST      (time, j, i) float32 dask.array<chunksize=(1, 1501, 1501), meta=np.ndarray>
#     SSU      (time, j, i_g) float32 dask.array<chunksize=(1, 1501, 1501), meta=np.ndarray>
#     SSV      (time, j_g, i) float32 dask.array<chunksize=(1, 1501, 1501), meta=np.ndarray>
#     oceTAUX  (time, j, i_g) float32 dask.array<chunksize=(1, 1501, 1501), meta=np.ndarray>
#     oceTAUY  (time, j_g, i) float32 dask.array<chunksize=(1, 1501, 1501), meta=np.ndarray>
#
#  data size: 154.9 GB

# %%
# %time ds.SSU.isel(time=1).plot()
# Out:
# CPU times: user 367 ms, sys: 149 ms, total: 516 ms
# Wall time: 5.84 s
